# %%
# !tar cvzf NegBio.tar.gz NegBio/
# Out:
# NegBio/
# NegBio/build/
# NegBio/build/lib/
# NegBio/build/lib/negbio/
# NegBio/build/lib/negbio/negbio_pipeline.py
# NegBio/build/lib/negbio/ngrex/
# NegBio/build/lib/negbio/ngrex/parser.py
# NegBio/build/lib/negbio/ngrex/parsetab.py
# NegBio/build/lib/negbio/ngrex/pattern.py
# NegBio/build/lib/negbio/ngrex/__init__.py
# NegBio/build/lib/negbio/negbio_neg.py
# NegBio/build/lib/negbio/neg/
# NegBio/build/lib/negbio/neg/utils.py
# NegBio/build/lib/negbio/neg/neg_detector.py
# NegBio/build/lib/negbio/neg/propagator.py
# NegBio/build/lib/negbio/neg/semgraph.py
# NegBio/build/lib/negbio/neg/__init__.py
# NegBio/build/lib/negbio/negbio_section_split.py
# NegBio/build/lib/negbio/negbio_neg_chexpert.py
# NegBio/build/lib/negbio/pipeline/
# NegBio/build/lib/negbio/pipeline/ptb2ud.py
# NegBio/build/lib/negbio/pipeline/scan.py
# NegBio/build/lib/negbio/pipeline/parse.py
# NegBio/build/lib/negbio/pipeline/negdetect.py
# NegBio/build/lib/negbio/pipeline/ssplit.py
# ...
